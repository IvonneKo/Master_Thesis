# %%
from tensorflow import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow_probability import distributions as tfd
from sklearn import preprocessing
from tensorflow.keras import backend as K
from tensorflow.keras import initializers


from sklearn.metrics import roc_auc_score
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model

import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2
from functions.vimlts import VimltsLinear
from functions.vimlts_fixBias import VimltsLinearB
from functions.sample_bernoulli_nll import sample_bernoulli_nll
from functions.scoreCI import score_ci
from functions.vimlts_fast_nullModel import VimltsLinearNull
import sys
print(sys.version)
print(tf.__version__)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 3.8.5 (default, Sep  4 2020, 07:30:14)
# [GCC 7.3.0]
# 2.4.1

# %%
# Load data
dat = pd.read_csv('../MA/patientData.csv')
train_dir = "./trainRes/"

# %%
np.random.seed(3004)
idx = np.arange(len(dat))
np.random.shuffle(idx)

# 80% training
train_idx = idx[:int(len(dat)*0.8)] 
# 20% test
test_idx = idx[int(len(dat)*0.8):] 
# 20% of training as validation
valid_idx = train_idx[:int(len(train_idx)*0.2)] 
train_idx = train_idx[int(len(train_idx)*0.2):]
print(train_idx.shape, valid_idx.shape, test_idx.shape)
# Out:
# (21200,) (5300,) (6626,)

# %%
X_train = dat.iloc[train_idx]
X_valid= dat.iloc[valid_idx]
X_test= dat.iloc[test_idx]
print(X_train.shape, X_valid.shape, X_test.shape)
y_train = dat.iloc[train_idx]
y_train = y_train.loc[:, y_train.columns.intersection(['target'])]
y_valid= dat.iloc[valid_idx]
y_valid = y_valid.loc[:, y_train.columns.intersection(['target'])]
y_test= dat.iloc[test_idx]
y_test = y_test.loc[:, y_train.columns.intersection(['target'])]
print(y_train.shape, y_valid.shape, y_test.shape)
# Out:
# (21200, 9) (5300, 9) (6626, 9)
# (21200, 1) (5300, 1) (6626, 1)

# %%
dat['age_approx'] = dat['age_approx'].fillna(dat['age_approx'].mean())
X_trainAge = dat.iloc[train_idx]
X_trainAge = X_train['age_approx']
X_validAge= dat.iloc[valid_idx]
X_validAge = X_valid['age_approx']
X_testAge= dat.iloc[test_idx]
X_testAge = X_test['age_approx']
print(X_trainAge.shape, X_validAge.shape, X_testAge.shape)
# Out:
# (21200,) (5300,) (6626,)

# %%
### standardized patients age
def standard(data):
    mean = np.mean(data)
    std = np.std(data)
    standard = (data - mean) / std
    return standard
standAge = standard(X_trainAge).ravel()
standAgeTr = pd.DataFrame({'age': standAge},columns=['age'])


standAgeValid = standard(X_validAge).ravel()
standAgeVal = pd.DataFrame({'age': standAgeValid},columns=['age'])

standAgeTest= standard(X_testAge).ravel()
standAgeTe = pd.DataFrame({'age': standAgeTest},columns=['age'])

np.std(standAgeTr), np.mean(standAgeTr)
# Out:
# (age    1.0
#  dtype: float64,
#  age    1.628009e-16
#  dtype: float64)

# %% [markdown]
# ## Functions

# %%
# manipulate tm-vi parameters
def softplus_inv(y):
    return np.log(np.exp(y) - 1)

# Log-Score   
def logScore(y_obs, y_pred):
    likelihoodElements= (y_obs*np.log(y_pred) + (1 - y_obs)*np.log(1 - y_pred))
    logScore = np.mean(likelihoodElements)
    return logScore.values[0]

# Prior
prior_dist=tfd.Normal(loc=0.,scale=1.)

# %% [markdown]
# ## Nullmodel only intercept

# %%
# range of thetas bernsteinpolynom
theta_start = -4
theta_stop = -2


# Number of samples to approximate the expected value
num_samples=1000
train_size= standAgeTr.shape[0]
# degree of bernsteinpolynom
M= 50 
# init params
kernel_initializers=dict(bias_init_alpha_w =initializers.Constant(1.),
                         bias_init_beta_w = initializers.Constant(0.),
                         bias_init_alpha_z = initializers.Constant(1.),
                         bias_init_beta_z = initializers.Constant(0.),
                         bias_init_thetas = [initializers.Constant(theta_start)] +[initializers.Constant(softplus_inv((theta_stop-theta_start)/(M))) for i in range(M)])

# Prior
x_in = Input(shape=(1,), name="VIMLTS_il")

x_arch = VimltsLinear(units=1,
                      activation=tf.keras.activations.sigmoid,
                      num_samples = 1000,
                      size= 21200,
                      **kernel_initializers,
                      prior_dist=prior_dist)(x_in)

model_VIMLTS = Model(x_in, x_arch, name="model_VIMLTS")
model_VIMLTS.summary()
# Out:
# Model: "model_VIMLTS"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# VIMLTS_il (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# vimlts_linear_2 (VimltsLinea (1000, None, 1)           61
# =================================================================
# Total params: 61
# Trainable params: 61
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 5000   ##to have the acurate posterior 
model_VIMLTS.compile(optimizer=Adam(lr=1e-4), loss=sample_bernoulli_nll, run_eagerly=False)
model_VIMLTS.fit(standAge, y_train,batch_size=256, epochs=epochs, verbose = True, callbacks=[LogKL()])

# %%
model_VIMLTS.compile(optimizer=Adam(lr=1e-4), loss=sample_bernoulli_nll, run_eagerly=False)
model_VIMLTS.fit(standAgeTr[:1], y_train[:1], verbose=True)
### save model weights
#model_VIMLTS.save_weights("../thesis/models/VITM-Tab_Intercept", save_format ="tf")

# %%
#recreate Model
model_VIMLTS.compile(optimizer=Adam(lr=1e-4), loss=sample_bernoulli_nll, run_eagerly=False)
#load the state of the old model
model_VIMLTS.load_weights("../thesis/models/VITM-Tab_Intercept")
layer = model_VIMLTS.layers[1]
qbNull,wNull = layer.get_b_dist()
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<functions.vimlts.VimltsLinear object at 0x7fe26482fe80> and <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fe26482fe20>).

# %% [markdown]
# ## TM_VI Modell 1 with fix intercept

# %%
##samples
num_samples=1000
train_size= standAgeTr.shape[0]


theta_start = 0.4
theta_stop = 0.7
# Number of samples to approximate the expected value


M = 50

# init params
kernel_initializers=dict(kernel_init_alpha_w =initializers.Constant(1.),               
                             kernel_init_beta_w = initializers.Constant(0.),
                             kernel_init_alpha_z = initializers.Constant(1.),
                             kernel_init_beta_z = initializers.Constant(0.),
                             kernel_init_thetas = [initializers.Constant(theta_start)] +
                             [initializers.Constant(softplus_inv((theta_stop-theta_start)/(M))) for i in range(M)]
                             )
# define model
# Prior
x_in = Input(shape=(1,), name="VIMLTS_il")

x_arch = VimltsLinearB(units=1,
                      activation=tf.keras.activations.sigmoid,
                      num_samples = 1000,
                      size= 21200,
                      **kernel_initializers,
                      prior_dist=prior_dist)(x_in)

modelFixIntercept = Model(x_in, x_arch, name="fix intercept")
modelFixIntercept.summary()
# Out:
# Model: "fix intercept"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# VIMLTS_il (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# vimlts_linear_b (VimltsLinea (1000, None, 1)           56
# =================================================================
# Total params: 56
# Trainable params: 55
# Non-trainable params: 1
# _________________________________________________________________

# %%
#### Train model
epochs = 5000   ##to have the acurate posterior 
#lr_callback = tf.keras.callbacks.LearningRateScheduler(partial(scheduler, lr_start=0.05, lr_stop=0.025, epochs=epochs))
modelFixIntercept.compile(optimizer=Adam(lr=1e-4), loss=sample_bernoulli_nll, run_eagerly=False)
modelFixIntercept.fit(standAge, y_train,batch_size=256, epochs=epochs, verbose = True, callbacks=[LogKL()])

# %%
### save model weights
#model.save_weights("models/VITM-FixIntercept-Tabular", save_format ="tf")

# %%
# model recreate
modelFixIntercept.compile(optimizer=Adam(lr=1e-4), loss=sample_bernoulli_nll, run_eagerly=False)
### load the state of the old model
modelFixIntercept.load_weights("../thesis/models/VITM-FixIntercept-Tabular")
layer = modelFixIntercept.layers[1]
qwFix, wFix = layer.get_w_dist()
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<functions.vimlts_fixBias.VimltsLinearB object at 0x7fe26453aac0> and <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7fe26443e5b0>).

# %% [markdown]
# ### M1: 2. VI-TM with slope and intercept

# %%
M=50
theta_start = -1
theta_stop = 1
delta_theta = softplus_inv((theta_stop-theta_start)/(M))
theta_startB = -5
theta_stopB = 5

vimlts_initializers=dict(kernel_init_alpha_w = initializers.Constant(1.),
                             kernel_init_beta_w = initializers.Constant(0.),
                             kernel_init_alpha_z = initializers.Constant(1.),
                             kernel_init_beta_z = initializers.Constant(0.),
                             kernel_init_thetas = [initializers.Constant(theta_start)] + 
                               [initializers.Constant(delta_theta) for _ in range(M)],
                             bias_init_alpha_w = initializers.Constant(1.),
                             bias_init_beta_w = initializers.Constant(0.),
                             bias_init_alpha_z = initializers.Constant(1.),
                             bias_init_beta_z = initializers.Constant(0.),
                             bias_init_thetas = [initializers.Constant(theta_startB)] +
                         [initializers.Constant(softplus_inv((theta_stopB-theta_startB)/(M))) for i in range(M)])

# %%
x_in = Input(shape=(1,), name="VIMLTS_il")

x_arch = VimltsLinear(units=1,
                      activation=tf.keras.activations.sigmoid,
                      num_samples = 1000,
                      size= 21200,
                      **vimlts_initializers,
                      prior_dist=prior_dist)(x_in)

SILSx = Model(x_in, x_arch, name="SI_LSx")
SILSx.summary()
# Out:
# Model: "SI_LSx"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# VIMLTS_il (InputLayer)       [(None, 1)]               0
# _________________________________________________________________
# vimlts_linear_7 (VimltsLinea (1000, None, 1)           110
# =================================================================
# Total params: 110
# Trainable params: 110
# Non-trainable params: 0
# _________________________________________________________________

# %%
### Train
epochs = 500
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
SILSx.compile(optimizer=Adam(lr=1e-4), loss=sample_bernoulli_nll, run_eagerly=False)
SILSx.fit(standAge, y_train,batch_size=256,validation_data =(standAgeValid,y_valid), epochs=epochs, 
                 verbose=True)
# Out:
# 2021-11-14 15:22:17.406869: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-11-14 15:22:17.424085: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2899885000 Hz
# Epoch 1/500
# WARNING:tensorflow:AutoGraph could not transform <function sample_bernoulli_nll at 0x7f2c2c00e8b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function sample_bernoulli_nll at 0x7f2c2c00e8b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 10/83 [==>...........................] - ETA: 0s - loss: 1.5458
# 2021-11-14 15:22:19.060776: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 83/83 [==============================] - 3s 15ms/step - loss: 1.5701 - val_loss: 1.5531
# Epoch 2/500
# 83/83 [==============================] - 1s 7ms/step - loss: 1.5200 - val_loss: 1.4816
# Epoch 3/500
# 83/83 [==============================] - 1s 7ms/step - loss: 1.4647 - val_loss: 1.4159
# Epoch 4/500
# 83/83 [==============================] - 1s 7ms/step - loss: 1.4030 - val_loss: 1.3643
# Epoch 5/500
# 83/83 [==============================] - 1s 7ms/step - loss: 1.3415 - val_loss: 1.3154
# Epoch 6/500
# 83/83 [==============================] - 1s 7ms/step - loss: 1.3040 - val_loss: 1.2653
# Epoch 7/500
# 83/83 [==============================] - 1s 6ms/step - loss: 1
500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0833 - val_loss: 0.0852
# Epoch 396/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0837 - val_loss: 0.0852
# Epoch 397/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0822 - val_loss: 0.0852
# Epoch 398/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0853 - val_loss: 0.0852
# Epoch 399/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0924 - val_loss: 0.0852
# Epoch 400/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0819 - val_loss: 0.0852
# Epoch 401/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0878 - val_loss: 0.0852
# Epoch 402/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0856 - val_loss: 0.0852
# Epoch 403/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0846 - val_loss: 0.0852
# Epoch 404/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0844 - val_loss: 0.0852
# Epoch 405/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0896 - val_loss: 0.0852
# Epoch 406/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0845 - val_loss: 0.0852
# Epoch 407/500
# 83/83 [==============================] - 1s 6ms/step - loss: 0.0819 - val_loss: 0.0852
# Epoch 408/500
# 83/83 [==============================] - 1s 6ms/step - loss: 0.0845 - val_loss: 0.0852
# Epoch 409/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0892 - val_loss: 0.0852
# Epoch 410/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0893 - val_loss: 0.0852
# Epoch 411/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0883 - val_loss: 0.0852
# Epoch 412/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0856 - val_loss: 0.0852
# Epoch 413/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0887 - val_loss: 0.0852
# Epoch 414/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0888 - val_loss: 0.0852
# Epoch 415/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0891 - val_loss: 0.0852
# Epoch 416/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0846 - val_loss: 0.0852
# Epoch 417/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0896 - val_loss: 0.0852
# Epoch 418/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0847 - val_loss: 0.0852
# Epoch 419/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0855 - val_loss: 0.0852
# Epoch 420/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0786 - val_loss: 0.0852
# Epoch 421/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0917 - val_loss: 0.0852
# Epoch 422/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0828 - val_loss: 0.0852
# Epoch 423/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0826 - val_loss: 0.0852
# Epoch 424/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0808 - val_loss: 0.0852
# Epoch 425/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0882 - val_loss: 0.0851
# Epoch 426/500
# 83/83 [==============================] - 0s 5ms/step - loss: 0.0842 - val_loss: 0.0851
# Epoch 427/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0880 - val_loss: 0.0852
# Epoch 428/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0868 - val_loss: 0.0852
# Epoch 429/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0865 - val_loss: 0.0852
# Epoch 430/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0858 - val_loss: 0.0852
# Epoch 431/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0832 - val_loss: 0.0852
# Epoch 432/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0868 - val_loss: 0.0852
# Epoch 433/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0859 - val_loss: 0.0852
# Epoch 434/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0836 - val_loss: 0.0852
# Epoch 435/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0862 - val_loss: 0.0852
# Epoch 436/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0865 - val_loss: 0.0852
# Epoch 437/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0892 - val_loss: 0.0851
# Epoch 438/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0847 - val_loss: 0.0851
# Epoch 439/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0874 - val_loss: 0.0851
# Epoch 440/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0830 - val_loss: 0.0851
# Epoch 441/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0827 - val_loss: 0.0852
# Epoch 442/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0800 - val_loss: 0.0851
# Epoch 443/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0914 - val_loss: 0.0851
# Epoch 444/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0814 - val_loss: 0.0852
# Epoch 445/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0851 - val_loss: 0.0851
# Epoch 446/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0854 - val_loss: 0.0852
# Epoch 447/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0881 - val_loss: 0.0851
# Epoch 448/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0860 - val_loss: 0.0851
# Epoch 449/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0879 - val_loss: 0.0852
# Epoch 450/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0906 - val_loss: 0.0851
# Epoch 451/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0873 - val_loss: 0.0851
# Epoch 452/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0850 - val_loss: 0.0851
# Epoch 453/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0872 - val_loss: 0.0852
# Epoch 454/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0924 - val_loss: 0.0852
# Epoch 455/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0887 - val_loss: 0.0851
# Epoch 456/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0897 - val_loss: 0.0851
# Epoch 457/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0805 - val_loss: 0.0851
# Epoch 458/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0867 - val_loss: 0.0851
# Epoch 459/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0911 - val_loss: 0.0851
# Epoch 460/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0810 - val_loss: 0.0852
# Epoch 461/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0863 - val_loss: 0.0851
# Epoch 462/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0872 - val_loss: 0.0851
# Epoch 463/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0860 - val_loss: 0.0851
# Epoch 464/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0905 - val_loss: 0.0851
# Epoch 465/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0869 - val_loss: 0.0851
# Epoch 466/500
# 83/83 [==============================] - 1s 6ms/step - loss: 0.0764 - val_loss: 0.0851
# Epoch 467/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0857 - val_loss: 0.0851
# Epoch 468/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0883 - val_loss: 0.0851
# Epoch 469/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0818 - val_loss: 0.0851
# Epoch 470/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0906 - val_loss: 0.0851
# Epoch 471/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0880 - val_loss: 0.0851
# Epoch 472/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0942 - val_loss: 0.0851
# Epoch 473/500
# 83/83 [==============================] - 1s 6ms/step - loss: 0.0858 - val_loss: 0.0851
# Epoch 474/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0865 - val_loss: 0.0851
# Epoch 475/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0858 - val_loss: 0.0851
# Epoch 476/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0862 - val_loss: 0.0851
# Epoch 477/500
# 83/83 [==============================] - 1s 6ms/step - loss: 0.0839 - val_loss: 0.0851
# Epoch 478/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0898 - val_loss: 0.0851
# Epoch 479/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0821 - val_loss: 0.0851
# Epoch 480/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0817 - val_loss: 0.0851
# Epoch 481/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0865 - val_loss: 0.0851
# Epoch 482/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0929 - val_loss: 0.0851
# Epoch 483/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0916 - val_loss: 0.0851
# Epoch 484/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0862 - val_loss: 0.0851
# Epoch 485/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0869 - val_loss: 0.0851
# Epoch 486/500
# 83/83 [==============================] - 1s 6ms/step - loss: 0.0898 - val_loss: 0.0851
# Epoch 487/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0880 - val_loss: 0.0851
# Epoch 488/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0833 - val_loss: 0.0851
# Epoch 489/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0848 - val_loss: 0.0851
# Epoch 490/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0831 - val_loss: 0.0851
# Epoch 491/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0866 - val_loss: 0.0851
# Epoch 492/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0920 - val_loss: 0.0851
# Epoch 493/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0831 - val_loss: 0.0851
# Epoch 494/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0862 - val_loss: 0.0851
# Epoch 495/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0842 - val_loss: 0.0851
# Epoch 496/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0849 - val_loss: 0.0851
# Epoch 497/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0830 - val_loss: 0.0851
# Epoch 498/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0878 - val_loss: 0.0851
# Epoch 499/500
# 83/83 [==============================] - 1s 6ms/step - loss: 0.0857 - val_loss: 0.0851
# Epoch 500/500
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0851 - val_loss: 0.0851

# %%
# save results
#dat = pd.DataFrame({'train_loss': SILSx.history.history['loss'], 
                       # 'val_loss': SILSx.history.history['val_loss']})
#dat.to_csv('../thesis/RunsTMVI_SILS/history.csv', index=False)

### save model weights
#SILSx.save_weights("models/VITM-Tabular", save_format ="tf")

# %% [markdown]
# ## Loss

# %%
loss_0 = pd.read_csv('../thesis/RunsTMVI_SILS/history.csv')
plt.figure(figsize=(13,15))
plt.subplot(221)
plt.plot(loss_0['train_loss'],label="Train Loss")
plt.plot(loss_0['val_loss'], label="Validation Loss")
plt.legend()
plt.title("Run0")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.ylim(0.08,0.15)
plt.yticks(np.arange(0.08, 0.15, 0.005))
plt.legend(fontsize='x-small')

#plt.savefig("./plots/uncertainty/LOSS_TMVI_SILSx.pdf")

# %%
### recreate Model

SILSx.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.05),metrics=[sample_bernoulli_nll], loss=sample_bernoulli_nll, run_eagerly=False)
### load the state of the old model
SILSx.load_weights("../thesis/models/VITM-Tabular")
##slope
layer = SILSx.layers[1]
qwSILS, wSILS = layer.get_w_dist()
##intercept
layer = SILSx.layers[1]
qbSILSx, bSILSx = layer.get_b_dist()

# %%
## sample direct
layer = SILSx.layers[1]
sampleW = layer.samplew()
#tabularSlopeIntercept = pd.DataFrame(list(zip(w, qw,b,qb,sampleW)),columns=['slope_weight',"slope_density","intercept_weight","intercept_density","sampleW"])
##tabularSlopeIntercept 
#tabularSlopeIntercept.to_csv("tabularSlope+Intercept.csv", index=False)

# %% [markdown]
# ## Performance

# %%
y_preds_SILSx = SILSx.predict(standAgeTe,batch_size=1)

# %%
samplesAllData = y_preds_SILSx.reshape(-1, 1000)
meanpred = samplesAllData.mean(axis=1)
predictions=meanpred.reshape(6626,1)

y_predictions_2p5Tab=np.quantile(samplesAllData,0.025,axis=1)
y_predictions_97p5Tab=np.quantile(samplesAllData,0.975,axis=1)

# %%
logScore(y_test,predictions)
# Out:
# -0.08502676937353977

# %%
###AUC
score, ci_lower, ci_upper, scores =score_ci(y_test, meanpred, score_fun=roc_auc_score)
print("AUC={:.2f}, 95% CI: {:.2f}-{:.2f}".format(score, ci_lower, ci_upper))
# Out:
# AUC=0.65, 95% CI: 0.60-0.70

# %% [markdown]
# ## Model with two components to have linear outcomes

# %%
M=50

theta_start = -1
theta_stop = 1


theta_startB = -5
theta_stopB = 5

vimlts_initializersLinearShift=dict(kernel_init_alpha_w = initializers.Constant(1.),
                             kernel_init_beta_w = initializers.Constant(0.),
                             kernel_init_alpha_z = initializers.Constant(1.),
                             kernel_init_beta_z = initializers.Constant(0.),
                             kernel_init_thetas = [initializers.Constant(theta_start)] +
                              [initializers.Constant(softplus_inv((theta_stop-theta_start)/(M))) for i in range(M)])

vimlts_initializersBias=dict(kernel_init_alpha_w = initializers.Constant(1.),
                             kernel_init_beta_w = initializers.Constant(0.),
                             kernel_init_alpha_z = initializers.Constant(1.),
                             kernel_init_beta_z = initializers.Constant(0.),
                             kernel_init_thetas = [initializers.Constant(theta_startB)] +
                              [initializers.Constant(softplus_inv((theta_stopB-theta_startB)/(M))) for i in range(M)])

prior_dist=tfd.Normal(loc=0.,scale=1.)

# %%
##Simple Intercept

in_ = keras.Input(shape = (1, ))
out_ = VimltsLinear(units=1,
                      activation=tf.keras.activations.linear,
                      num_samples=1000,
                      size = 21200,
                      **vimlts_initializersBias,
                      prior_dist=prior_dist)(in_)
SI = keras.Model(inputs = in_, outputs = out_,name = "SI")

# %%
##### Tabular Data 

### Kein Bias Bei Linear Shift

inCov = keras.Input(shape = 1, name = 'inCov')
outCov = VimltsLinear(units=1,
                      activation=tf.keras.activations.linear,
                      num_samples=1000,
                      size = 21200,
                      **vimlts_initializersLinearShift,
                      prior_dist=prior_dist)(inCov)

LS = keras.Model(inputs = inCov, outputs = outCov,name = "LS")
LS.summary()
# Out:
# Model: "LS"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inCov (InputLayer)           [(None, 1)]               0
# _________________________________________________________________
# vimlts_linear_20 (VimltsLine (1000, None, 1)           55
# =================================================================
# Total params: 55
# Trainable params: 55
# Non-trainable params: 0
# _________________________________________________________________

# %%
  ##add 
def modelOn(X_meta, X):
    added = tf.keras.layers.Add()([X_meta.output, X.output]) 
    out = tf.math.sigmoid(added)
    model1 = keras.Model(inputs = [X_meta.input, X.input], outputs = out)
    return model1 
model = modelOn(SI,LS)
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.momentum
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.rho
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
# define model

model.compile(loss=sample_bernoulli_nll, optimizer=Adam(1e-4),run_eagerly=False)

# %%
results = model.fit(x=[np.ones((y_train.shape[0], 1)), standAge],
                        y = y_train,
                        validation_data = ([np.ones((y_valid.shape[0], 1)), standAgeValid], y_valid),
                        batch_size=256,
                        epochs = 3000,
                        verbose= True,
                       )
# Out:
# Epoch 1/5000
# 83/83 [==============================] - 3s 13ms/step - loss: 1.6663 - val_loss: 1.5946
# Epoch 2/5000
# 83/83 [==============================] - 1s 7ms/step - loss: 1.5921 - val_loss: 1.5466
# Epoch 3/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 1.5307 - val_loss: 1.4853
# Epoch 4/5000
# 83/83 [==============================] - 1s 6ms/step - loss: 1.4757 - val_loss: 1.4346
# Epoch 5/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 1.4124 - val_loss: 1.3852
# Epoch 6/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 1.3785 - val_loss: 1.3451
# Epoch 7/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 1.3145 - val_loss: 1.2737
# Epoch 8/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 1.2666 - val_loss: 1.2382
# Epoch 9/5000
# 83/83 [==============================] - 1s 6ms/step - loss: 1.2302 - val_loss: 1.1838
# Epoch 10/5000
# 83/83 [==============================] - 1s 6ms/step - loss: 1.1782 - val_loss: 1.1502
# Epoch 11/5000
# 83/83 [==============================] - 1s 6ms/step - loss: 1.1463 - val_loss: 1.0964
# Epoch 12/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 1.0893 - val_loss: 1.0658
# Epoch 13/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 1.0503 - val_loss: 1.0309
# Epoch 14/5000
# 83/83 [==============================] - 1s 6ms/step - loss:
5000
# 83/83 [==============================] - 1s 6ms/step - loss: 0.0842 - val_loss: 0.0851
# Epoch 4986/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0836 - val_loss: 0.0851
# Epoch 4987/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0873 - val_loss: 0.0851
# Epoch 4988/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0852 - val_loss: 0.0850
# Epoch 4989/5000
# 83/83 [==============================] - 1s 6ms/step - loss: 0.0838 - val_loss: 0.0851
# Epoch 4990/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0856 - val_loss: 0.0851
# Epoch 4991/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0852 - val_loss: 0.0851
# Epoch 4992/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0848 - val_loss: 0.0851
# Epoch 4993/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0896 - val_loss: 0.0851
# Epoch 4994/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0857 - val_loss: 0.0851
# Epoch 4995/5000
# 83/83 [==============================] - 1s 6ms/step - loss: 0.0853 - val_loss: 0.0851
# Epoch 4996/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0838 - val_loss: 0.0850
# Epoch 4997/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0851 - val_loss: 0.0851
# Epoch 4998/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0897 - val_loss: 0.0850
# Epoch 4999/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0832 - val_loss: 0.0851
# Epoch 5000/5000
# 83/83 [==============================] - 0s 6ms/step - loss: 0.0877 - val_loss: 0.0850

# %%
### save model weights
#model.save_weights("../thesis/models/VITM-TabularComponents", save_format ="tf")
#LS.save_weights("../thesis/models/VITM-TabularComponentsTab", save_format ="tf")

# %%
model.compile(optimizer=Adam(lr=1e-4), loss=sample_bernoulli_nll, run_eagerly=False)

### load the state of the old model
model.load_weights("../thesis/models/VITM-TabularComponents")

###slope
layer = LS.layers[1]
qwLS, wLS = layer.get_w_dist()

##intercept
layer = SI.layers[1]
qwSI, wSI = layer.get_w_dist()

# %%
### save model weights
#model.save_weights("models/VITM-TabularComponents", save_format ="tf")
#nn_tab1.save_weights("models/VITM-TabularComponentsTab", save_format ="tf")

# %%
xtest= [np.ones((y_test.shape[0], 1)), standAgeTe]
y_preds_SI_LSx2 = model.predict(xtest,batch_size=1)

# %%
samplesAllData = y_preds_SI_LSx2.reshape(-1, 1000)
meanpred = samplesAllData.mean(axis=1)

predictions=meanpred.reshape(6626,1)

y_predictions_2p5Tab=np.quantile(samplesAllData,0.025,axis=1)
y_predictions_97p5Tab=np.quantile(samplesAllData,0.975,axis=1)

# %%
logScore(y_test,predictions)
# Out:
# -0.08499053583445701

# %%
###AUC
score, ci_lower, ci_upper, scores =score_ci(y_test, meanpred, score_fun=roc_auc_score)
print("AUC={:.2f}, 95% CI: {:.2f}-{:.2f}".format(score, ci_lower, ci_upper))
# Out:
# AUC=0.66, 95% CI: 0.61-0.71

# %% [markdown]
# ## Posterior distribution of slope compared to true MCMC posterior

# %% [markdown]
# ## Posterior predictive distribution

# %%
oodTabNegative = np.arange(-10, -4, 0.1)
oodTabPositive = np.arange(4, 10, 0.1)
oodTab = [*oodTabNegative, *oodTabPositive]
oods = pd.DataFrame(oodTab)

sortX = standAgeTe[0:120].sort_values("age", ascending = True)
data = []

# extreme value -10,10

data.insert(0, {'age': -10})
data.insert(0, {'age': 10})


negative=pd.DataFrame(oodTabNegative)
r=oods.rename(columns={0: 'age'})
s =pd.concat([pd.DataFrame(data), sortX,r], ignore_index=False) # does not save changes to the original dataframe

sortAgeTest = s.sort_values("age", ascending = True)
sortAgeTest
# Out:
#       age
# 0   -10.0
# 1   -10.0
# 1    -9.9
# 2    -9.8
# 3    -9.7
# ..    ...
# 116   9.6
# 117   9.7
# 118   9.8
# 119   9.9
# 0    10.0
#
# [242 rows x 1 columns]

# %%
# VIMLTS
beta_list = []
xtestOO= [np.ones((sortAgeTest.shape[0], 1)), sortAgeTest]

import tqdm
# Iterate over number of predictions
for i in tqdm.tqdm(range(100)):
    # VIMLTS

    y_pred_VIMLTS = model.predict(xtestOO,batch_size=242)[0]
    beta_list.append(y_pred_VIMLTS)

y_preds = np.concatenate(beta_list, axis=1)
y_predictions_mean=np.mean(y_preds,axis=1)
y_predictions_2p5=np.quantile(y_preds,0.025,axis=1)
y_predictions_97p5=np.quantile(y_preds,0.975,axis=1)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 37.52it/s]

# %%
##logit
# VIMLTS
beta_listOdds = []
xtestOO= [np.ones((sortAgeTest.shape[0], 1)), sortAgeTest]
intermediate_layer_model = Model(inputs=model.input, outputs=model.layers[4].output)
import tqdm
# Iterate over number of predictions
for i in tqdm.tqdm(range(100)):
    # VIMLTS

    y_pred_VIMLTSOdds = intermediate_layer_model.predict(xtestOO,batch_size=242)[0]
    beta_listOdds.append(y_pred_VIMLTSOdds)

y_predsOdds = np.concatenate(beta_listOdds, axis=1)
y_predictionsOdds_mean=np.mean(y_predsOdds,axis=1)
y_predictions_2p5Odds=np.quantile(y_predsOdds,0.025,axis=1)
y_predictions_97p5Odds=np.quantile(y_predsOdds,0.975,axis=1)
# Out:
# 100%|██████████| 100/100 [00:02<00:00, 38.41it/s]

# %%
# 1. logit!
intermediate_layer_model = Model(inputs=model.input, outputs=model.layers[4].output)

xtest= [np.ones((120, 1)), standAgeTest[0:120]]
y_predsLS = intermediate_layer_model.predict(xtest,batch_size=1)
samplesAllData = y_predsLS.reshape(-1, 1000)
meanpred = samplesAllData.mean(axis=1)
predictions=meanpred.reshape(120,1)




y_predictions_25Tab=np.quantile(samplesAllData,0.25,axis=1)
y_predictions_75Tab=np.quantile(samplesAllData,0.75,axis=1)

# 2. OOD
##OOD prediction paar daten positiv und negative richtung

#oodTab = [-5,-6,-7,-8,-9,-10,5,6,7,8,9,10]

xtestOOD= [np.ones((oods.shape[0], 1)), oods]
y_predTabOOD = intermediate_layer_model.predict(xtestOOD,batch_size =1)

samplesTabOOD = y_predTabOOD.reshape(-1, 1000) ###every datapoint one sample
meanpredTabOOD = samplesTabOOD.mean(axis=1)  ###mean samples 
predictionsTabOOD=meanpredTabOOD.reshape(120,1)

y_predictions_25TabOOD=np.quantile(samplesTabOOD,0.25,axis=1)
y_predictions_75TabOOD=np.quantile(samplesTabOOD,0.75,axis=1)


##dataframe
tabCenterOOD = [sublist[-1] for sublist in predictionsTabOOD]
tabLowOOD = [sublist[-1] for sublist in y_predictions_25TabOOD.reshape(120,1)]
tabHighOOD = [sublist[-1] for sublist in y_predictions_75TabOOD.reshape(120,1)]
widthOOD= [x1 - x2 for (x1, x2) in zip(tabHighOOD, tabLowOOD)]

# %%
## vorbereitung tabular

tabCenter = [sublist[-1] for sublist in meanpred.reshape(120,1)]
tabLow = [sublist[-1] for sublist in y_predictions_25Tab.reshape(120,1)]
tabHigh = [sublist[-1] for sublist in y_predictions_75Tab.reshape(120,1)]
width= [x1 - x2 for (x1, x2) in zip(tabHigh, tabLow)]


tabulardata = pd.DataFrame(
    {'width': width,
     'center': tabCenter
    })

###Out of distribution

tabulardataOOD = pd.DataFrame(
    {'width': widthOOD,
     'center': tabCenterOOD
    })

# %%
sort = standAgeTr.sort_values("age", ascending = True)

# %%
fig = plt.figure(figsize=(20,8))

plt.rcParams.update(({'font.size': 30}))



fig.add_subplot(121)
plt.fill_between(sortAgeTest.values.reshape(-1),y_predictions_97p5Odds,y_predictions_2p5Odds, 
                color='blue', alpha=0.08, label=(r"95% PI"))




plt.plot(sortAgeTest.values.reshape(-1),y_predictionsOdds_mean, color='black' ,label=("TM-VI \nmean"))

plt.plot(sortAgeTest.values.reshape(-1),y_predictions_2p5Odds, color='grey',linewidth=3,linestyle=(0, (3, 1, 1, 1, 1, 1)))
plt.plot(sortAgeTest.values.reshape(-1),y_predictions_97p5Odds, color='grey',linewidth=3,linestyle=(0, (3, 1, 1, 1, 1, 1)))
plt.text(-14.5, 5.5,"A", 
            size=30, weight='bold')
plt.axvline(-3, 0, 1, label='ID',linestyle="dotted",color="orange")
plt.axvline(3, 0, 1,linestyle="dotted",color="orange")

plt.legend(fontsize=25)
plt.xlabel("standardized age")
plt.ylabel("$z$")
plt.yticks(np.arange(-15, 10, step=5))
plt.xticks(np.arange(-10, 15, step=5))



#fig.add_subplot(122)
#plt.scatter(imagadataOODWholeA["center"],imagadataOODWholeA["width"],label="TM-VI\nOOD (modified)",alpha=0.3,s=20,color="dodgerblue")
#plt.scatter(imagadataOODWhole["center"],imagadataOODWhole["width"],label="TM-VI\nOOD (random)",alpha=0.7,s=20,color="darkblue")
#plt.scatter(imagedataWhole["center"],imagedataWhole["width"],label="TM-VI ID",alpha=0.3,s=20,color="orange")
#plt.legend(fontsize=13)
#plt.ylabel("interquartile range")
#plt.xlabel("mean $\sigma(\\vartheta(B)$)")
#plt.yticks(np.arange(0, 0.1, 0.025))
#plt.xticks(np.arange(0, 1.2, 0.2))


fig.add_subplot(122)
plt.fill_between(sortAgeTest.values.reshape(-1),y_predictions_97p5,y_predictions_2p5, 
                color='blue', alpha=0.08, label=(r"95% PI"))




plt.plot(sortAgeTest.values.reshape(-1),y_predictions_mean, color='black' ,label=("TM-VI \nmean"))

plt.plot(sortAgeTest.values.reshape(-1),y_predictions_2p5, color='grey',linewidth=3,linestyle=(0, (3, 1, 1, 1, 1, 1)))
plt.plot(sortAgeTest.values.reshape(-1),y_predictions_97p5, color='grey',linewidth=3,linestyle=(0, (3, 1, 1, 1, 1, 1)))

plt.scatter(standAgeTest,y_test, color='orange', s=10,alpha=0.5,label="Test data")
plt.text(-14.5, 1.07,"B", 
            size=30, weight='bold')
plt.legend(loc="center left",fontsize=25)

#plt.yticks(np.arange(-2.0, 1.5, 0.1))
#plt.ylabel("$p(y=1|D)$")
plt.xlabel("standardized age")
plt.ylabel("$p (y=1|x)$")
plt.yticks(np.arange(0., 1.2, step=0.2))
plt.xticks(np.arange(-10, 15, step=5))


fig.tight_layout(pad=1.5)
#plt.savefig("./plots/uncertainty/TabularPPD.pdf")
